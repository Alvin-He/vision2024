# %%
from ultralytics import YOLO
import numpy as np
import cv2

# %%
# 90 degrees based on camera manufacturer
HORIZONTAL_FOV = 90

def calculate_rotation_angle(xmin, xmax, image_width):
    cx = (xmin + xmax) / 2
    dx = cx - image_width / 2
    theta = (dx / (image_width / 2)) * (HORIZONTAL_FOV / 2)
    return theta

# %%
# Load the Ultralytics model
model = YOLO('../models/YOLOv8nNORO.pt')

# Open a handle to the default webcam
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open webcam")

# Set window name
window_name = 'Live Video'

while True:
    # Read a new frame from the webcam
    ret, frame = cap.read()
    if not ret:
        break

    # Convert frame from BGR to RGB
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Perform inference
    results = model(frame_rgb)

    for res in results:
        # Draw the bounding boxes and labels on the frame
        for box in res.boxes:
            # Extract bounding box coordinates
            xmin, ymin, xmax, ymax = map(int, box.xyxy.squeeze())
            label = res.names[int(box.cls)]  # Get the class name using the detected class index
            confidence = float(box.conf)  # Confidence score
            
            xmin_percent, _, _, _ = map(float, box.xyxyn.squeeze())
            image_width = xmin / xmin_percent
            print(calculate_rotation_angle(xmin, xmax, image_width))

            # Draw the bounding box
            cv2.rectangle(frame, (xmin, ymin), (xmax, ymax), (0, 255, 0), 2)
            
            # Draw the label and confidence score
            text = f'{label} {confidence:.2f}'
            cv2.putText(frame, text, (xmin, ymin-5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Display the resulting frame
    cv2.imshow(window_name, frame)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1000) == ord('q'):
        break

# Release the VideoCapture and destroy all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 note, 72.1ms
# Speed: 1.7ms preprocess, 72.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 84.2ms
# Speed: 4.9ms preprocess, 84.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 121.2ms
# Speed: 3.3ms preprocess, 121.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 96.4ms
# Speed: 32.8ms preprocess, 96.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 107.2ms
# Speed: 11.3ms preprocess, 107.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 86.1ms
# Speed: 3.7ms preprocess, 86.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 106.8ms
# Speed: 3.9ms preprocess, 106.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 71.4ms
# Speed: 3.5ms preprocess, 71.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 69.1ms
# Speed: 2.9ms preprocess, 69.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 117.2ms
# Speed: 3.8ms preprocess, 117.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 109.6ms
# Speed: 3.5ms preprocess, 109.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 66.6ms
# Speed: 3.8ms preprocess, 66.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 104.9ms
# Speed: 4.2ms preprocess, 104.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 104.9ms
# Speed: 7.9ms preprocess, 104.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 90.7ms
# Speed: 3.4ms preprocess, 90.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 robot, 90.1ms
# Speed: 3.7ms preprocess, 90.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 robot, 81.7ms
# Speed: 3.9ms preprocess, 81.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 robot, 87.3ms
# Speed: 4.1ms preprocess, 87.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 79.3ms
# Speed: 4.2ms preprocess, 79.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 148.7ms
# Speed: 3.2ms preprocess, 148.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 95.5ms
# Speed: 3.3ms preprocess, 95.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 68.2ms
# Speed: 3.8ms preprocess, 68.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 86.0ms
# Speed: 2.8ms preprocess, 86.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 78.0ms
# Speed: 3.5ms preprocess, 78.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 56.6ms
# Speed: 5.4ms preprocess, 56.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 71.3ms
# Speed: 3.3ms preprocess, 71.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 67.7ms
# Speed: 2.9ms preprocess, 67.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 68.5ms
# Speed: 3.5ms preprocess, 68.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 109.4ms
# Speed: 4.0ms preprocess, 109.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 80.0ms
# Speed: 3.5ms preprocess, 80.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 66.0ms
# Speed: 3.6ms preprocess, 66.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 58.8ms
# Speed: 2.9ms preprocess, 58.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 59.6ms
# Speed: 3.0ms preprocess, 59.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 94.5ms
# Speed: 3.7ms preprocess, 94.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 127.2ms
# Speed: 5.0ms preprocess, 127.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 91.8ms
# Speed: 5.0ms preprocess, 91.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 57.6ms
# Speed: 3.4ms preprocess, 57.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 robot, 1 note, 94.4ms
# Speed: 18.0ms preprocess, 94.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 note, 89.0ms
# Speed: 2.9ms preprocess, 89.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.0ms
# Speed: 3.8ms preprocess, 78.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 robot, 97.0ms
# Speed: 3.3ms preprocess, 97.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 robot,